# %% [markdown]
# # Project Part 1
#
# [![Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://kaggle.com/kernels/welcome?src=https://github.com/sgeinitz/cs39aa_project/blob/main/project_part1.ipynb)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sgeinitz/cs39aa_project/blob/main/project_part1.ipynb)
#
# Daniel Sherman Project Part 1

# %% [markdown]
# ## Introduction/Background
#
#     For this project I will be taking the following dataset of reddit posts from many top technology related subreddits. Using the data within the set, I plan to try to predict whether a technology based reddit post would be informative vs entertainment using the language used in the title of the post, any text in the body of the post, and the language used in the comments of the post. This is a text classification problem because I will be using word usage and frequency to determine a binary label between "informative" and "entertaining" posts. The dataset to be used is linked below.
#
# * https://www.kaggle.com/datasets/mohamedkhaledelsafty/top-10-tech-subreddits?select=combined_subreddits.csv

# %% [markdown]
# ## Exploratory Data Analysis
#
# _You will now load the dataset and carry out some exploratory data analysis steps to better understand what text data looks like. See the examples from class on 10/. The following links provide some good resources of exploratory analyses of text data with Python._
#
#
# * https://neptune.ai/blog/exploratory-data-analysis-natural-language-processing-tools
# * https://regenerativetoday.com/exploratory-data-analysis-of-text-data-including-visualization-and-sentiment-analysis/
# * https://medium.com/swlh/text-summarization-guide-exploratory-data-analysis-on-text-data-4e22ce2dd6ad
# * https://www.kdnuggets.com/2019/05/complete-exploratory-data-analysis-visualization-text-data.html

# %%
# import all of the python modules/packages you'll need here
import pandas as pd
# ...
